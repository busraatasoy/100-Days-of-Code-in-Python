# %% [markdown]
# <a href="https://colab.research.google.com/github/busraatasoy/100-Days-of-Code-in-Python/blob/main/Day_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 08: Function Parameters & Caesar Cipher

# %% [markdown]
# ##**Functions with Inputs**

# %%
# Functions :

def my_function():
		# Do this
		# Then do this
		# Finally do this

  my_function()   #call the function

# %%
# Example :

def greet():
		print("Hello")
		print("How do you do?")
		print("Isn't the weather nice?")

greet()
# Out:
# Hello
# How do you do?
# Isn't the weather nice?

# %% [markdown]
# **Functions with Inputs :**

# %%
# Functions that allows for inputs

def my_function(something):
		# Do this with something
		# Then do this
		# Finally do this

  my_function()   #call the function

# %%
# Example :
# Functions that allows for inputs

def greet_with_name(name):
		print(f"Hello {name}")
		print(f"How do you do {name}?")

greet_with_name("Angela")   #call the function

#Attention: When I changed the name like "Sara", def function is running the that name.
# Out:
# Hello Angela
# How do you do Angela?

# %% [markdown]
# In programming lingo, you’ll hear this being referred to as the Parameter, and this piece of data being referred to as the Argument.
#
# my_function(something)
#
# something = 123
#
# (Parameter)     (Argument)
#
# **The argument is the actual piece of data** thet’s going to be passed over to this function when it’s being called, whereas **the parameter is the name of that data,** and we use the parameter inside the function to refer to it and to do things with it.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Life in Weeks - Coding Exercise**

# %% [markdown]
# I was reading this article by Tim Urban -[Your Life in Weeks](https://waitbutwhy.com/2014/05/life-weeks.html) and realised just how little time we actually have.
#
# Create a function called `life_in_weeks()` using maths and f-Strings that tells us how many weeks we have left, if we live until 90 years old.
#
# It will take your current age as the input and output a message with our time left in this format:
#
# `You have x weeks left.`
#
# Where x is replaced with the actual calculated number of weeks the input age has left until age 90.
#
# - The function must be called `life_in_weeks` for the tests to pass. Also the output must have the same punctuation and spelling as the example. Including the full stop!
#
# **Example Input**
#
# `56`
#
# **Example Output**
#
# `You have 1768 weeks left.`
#
# **How to test your code and see your output?**
#
# Udemy coding exercises do not have a console, so you cannot use `input()`. You will need to call your function with hard-coded values like so:
#
# def life_in_weeks(age): `
#
# ......   your code here`

# %%
# Solution 1 - Short Version:

def life_in_weeks(age):
    print(f"You have {((90-age)*52)} weeks left.")

life_in_weeks(20)

# Output
# You have 3640 weeks left.
# Out:
# You have 3640 weeks left.

# %%
# Solution 2 - Long Version:

def life_in_weeks(age):
    years_remaining = 90 - age
    weeks_remaining = years_remaining * 52
    print(f"You have {weeks_remaining} weeks left.")


life_in_weeks(20)
# Out:
# You have 3640 weeks left.

# %% [markdown]
# ## Positional vs. Keyword Arguments

# %%
# Functions with more than 1 input:

def greet_with(name, location):
		print(f"Hello {name}")
		print(f"What is it like in {location}?")

greet_with("Büşra", "İstanbul")   #call the function
# Out:
# Hello Büşra
# What is it like in İstanbul?

# %% [markdown]
# **Attention!:** If I changed the argument, output is changed:

# %%
# Functions with more than 1 input:

def greet_with(name, location):
		print(f"Hello {name}")
		print(f"What is it like in {location}?")

greet_with("İstanbul", "Büşra")   #call the function
# Out:
# Hello İstanbul
# What is it like in Büşra?

# %% [markdown]
# **Positional Arguments :**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Output: a=1, b=2, c=3
#
# If I changed the inputs, outputs are changed.
#
# my_function(3, 1, 2)
#
# **Output:** a=3, b=1, c=2
#
# **But I find the solution;**
#
# **Keyword Arguments :**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **If I use keyword argument and changed the argument position; output is not changed:**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Function with more inputs -Keyword Argument:**

# %%
# Functions with more than 1 input:

def greet_with(name, location):
		print(f"Hello {name}")
		print(f"What is it like in {location}?")

greet_with(name = "Büşra", location = "İstanbul")   #call the function
# Out:
# Hello Büşra
# What is it like in İstanbul?

# %%
# Attention!: If I changed the position, output is not changed.
# Functions with more than 1 input:

def greet_with(name, location):
		print(f"Hello {name}")
		print(f"What is it like in {location}?")

greet_with(location = "İstanbul", name = "Büşra",)   #call the function
# Out:
# Hello Büşra
# What is it like in İstanbul?

# %% [markdown]
# ## **Love Calculator - Coding Exercise**

# %% [markdown]
# **Love Calculator**
#
# 💪 This is a difficult challenge! 💪
#
# You are going to write a function called `calculate_love_score()` that tests the compatibility between two names.  To work out the love score between two people:
#
# 1. Take both people's names and check for the number of times the letters in the word TRUE occurs.
#
# 2. Then check for the number of times the letters in the word LOVE occurs.
#
# 3. Then combine these numbers to make a 2 digit number and print it out.
#
# e.g.
#
# `name1 = "Angela Yu" name2 = "Jack Bauer"`
#
# T occurs 0 times
#
# R occurs 1 time
#
# U occurs 2 times
#
# E occurs 2 times
#
# **Total = 5**
#
# L occurs 1 time
#
# O occurs 0 times
#
# V occurs 0 times
#
# E occurs 2 times
#
# **Total = 3**
#
# **Love Score = 53**
#
# **Example Input**
#
# `calculate_love_score("Kanye West", "Kim Kardashian")`
#
# **Example Output**
#
# 42
#
# **How to test your code and see your output?**
#
# Udemy coding exercises do not have a console, so you cannot use the `input()` function. You will need to call your function with hard-coded values like so:
#
# `def calculate_love_score(name1, name2):
#
# ....your code here
#
# Call your function with hard coded values
#
#   calculate_love_score("Kanye West", "Kim Kardashian")`

# %%
#Solution 1:
def calculate_love_score(name1, name2):
    combined_names = (name1 + name2).lower()

    true_count = 0
    for letter in "true":
        true_count += combined_names.count(letter)

    love_count = 0
    for letter in "love":
        love_count += combined_names.count(letter)

    love_score = int(str(true_count) + str(love_count))
    print(love_score)

calculate_love_score("Kanye West", "Kim Kardashian")
# Out:
# 42

# %% [markdown]
# **Tips:**
#
# **These functions will help you:**
#
# You can use the`count()`function to count the number of times a character occurs in a string.
#
# Docs: [link](https://www.w3schools.com/python/ref_list_count.asp)
#
# You can use the `lower()`function to change all the inputs to lower case. Docs: [string lower link](https://www.w3schools.com/python/ref_string_lower.asp)

# %%
# Solution 2:

def calculate_love_score(name1, name2):
    combined_names = name1 + name2     #sum names
    lower_names = combined_names.lower()  #to change all the inputs to lower case

    t = lower_names.count("t")    #to count the number of times a character occurs in a string. Docs:
    r = lower_names.count("r")
    u = lower_names.count("u")
    e = lower_names.count("e")
    first_digit = t + r + u + e

    l = lower_names.count("l")
    o = lower_names.count("o")
    v = lower_names.count("v")
    e = lower_names.count("e")
    second_digit = l + o + v + e


    score = int(str(first_digit) + str(second_digit))
    print(score)

calculate_love_score("Kanye West", "Kim Kardashian")
# Out:
# 42
